# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import pandas as pd
import seaborn as sns
import pickle
import cvxpy
from cvxpy import *
from sklearn.preprocessing import Normalizer 
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from copy import deepcopy

# %%
# plt.style.use('default')
plt.rcParams.update({'font.size':18})
figDir = '/Users/aqib/Desktop/UCSB/research/BCCL/structured-dmd/NSBA_submission/figures/'
my_cmap = sns.diverging_palette(15, 221, s=99, sep=1, l=45, center='light',as_cmap=True)
# sns.choose_diverging_palette()

# %%
def snapshots_from_df(df):

    strains = ['wt','icar','phlf','nand']
    tps = ['5','18']
    temps = ['30','37']
    inducers = ['00','10','01','11']

    # create a dictionary where you specify strain, temp, and inducers as keys to grab the snapshot matrices
    snapshot_dict = {}
    for strain in strains: 
        snapshot_dict[strain] = {}
        for temp in temps: 
            snapshot_dict[strain][temp] = {}
            for inducer in inducers: 
                snapshot_dict[strain][temp][inducer] = {} # keys are to be Yf and Yp
                # get substring of colname that identifies the group (so everything except rep number)
                yp_colname = strain + '_' + inducer + temp + tps[0]
                # get list of indices that correspond to this group (in short, grabbing inds for all replicates)
                yp_col_inds = [ii for ii, this_col in enumerate(list(df.columns)) if yp_colname in this_col]
                snapshot_dict[strain][temp][inducer]['Yp'] = np.array(df.iloc[:,yp_col_inds])
                # do the same for the 18 hours timepoint i.e. Yf
                yf_colname = strain + '_' + inducer + temp + tps[1]
                yf_col_inds = [ii for ii, this_col in enumerate(list(df.columns)) if yf_colname in this_col]
                snapshot_dict[strain][temp][inducer]['Yf'] = np.array(df.iloc[:,yf_col_inds])
                
    return snapshot_dict

def get_unpaired_samples(df):
    # filter the samples that don't have a timepoint pair due to low sequencing depth
    unpaired_samples = []
    for sample in df.columns: 
        if '5' in sample:
            if sample.replace('5','18') not in df.columns:
#                 print(sample,sample.replace('5','18'))
                unpaired_samples.append(sample)
        elif '18' in sample: 
            if sample.replace('18','5') not in df.columns:
#                 print(sample,sample.replace('18','5'))
                unpaired_samples.append(sample)
    return unpaired_samples

def apply_normalizer(Yp,Yf):
    # normalize each datapoint individually
    transformer1 = Normalizer().fit(Yp.T)
    Yp_normed = transformer1.transform(Yp.T).T

    transformer2 = Normalizer().fit(Yf.T)
    Yf_normed = transformer2.transform(Yf.T).T
    return Yp_normed,Yf_normed

# %%
def calc_Koopman(Yf,Yp,flag=1,lambda_val=0.0,noise_scaler=1,verbose=True):
    
    ngenes = Yf.shape[0]
    ndatapts = Yf.shape[1]
    
    if flag == 1: # least-squares solution
        Yp_inv = np.linalg.pinv(Yp)
        K = np.dot(Yf,Yp_inv)
        print('The mean squared error is: ' + '{:0.3e}'.format(np.linalg.norm(K@Yp - Yf)**2 / ndatapts)) 

        # TO DO: Add SVD based DMD for modal decompostion (modes can be insightful)
        
    if flag == 2: # robust optimization approach
        
        solver_instance = cvxpy.SCS
                
        operator = Variable(shape=(ngenes,ngenes)) # Koopman matrix  K
        
        if type(lambda_val) == float:
            reg_term = lambda_val * cvxpy.norm(operator,p=1) 
        else:
            lambda_val = np.reshape(lambda_val,(len(lambda_val),1))
            Unoise = np.tile(lambda_val,ndatapts)
            reg_term = cvxpy.norm(cvxpy.matmul(operator + np.eye(ngenes),noise_scaler*Unoise),p='fro') # where exactly does this term come from? 

        print("[INFO]: CVXPY Koopman operator variable: " + repr(operator.shape))
        print("[INFO]: Shape of Yf and Yp: " + repr(Yf.shape) + ', ' + repr(Yp.shape) )
        norm2_fit_term = cvxpy.norm(Yf - cvxpy.matmul(operator,Yp),p=2) 
        objective = Minimize(norm2_fit_term + reg_term)
        constraints = []
        prob = Problem(objective,constraints)
        result = prob.solve(verbose=verbose,solver=solver_instance,max_iters=int(1e6))
        print("[INFO]: CVXPY problem status: " + prob.status)
        K = operator.value
        print('MSE =  ' + '{:0.3e}'.format(np.linalg.norm(K@Yp - Yf)**2 / ndatapts)) 

    return K

# %% [markdown]
# #### Reproducing lac and ara host dynamics analysis from BioCAS paper

# %%
# load relevant dataframes
df_cts_filter = pd.read_csv('data/count_matrix_NAND.csv')
unpaired_samples = get_unpaired_samples(df_cts_filter)
all_genes_filter =  df_cts_filter['gene']
df_tpm_filter = (pd.read_csv('data/TPM_matrix_NAND.csv')).iloc[:,1:]
df_tpm_filter = df_tpm_filter.drop(columns=unpaired_samples).reset_index(drop=True)

# %%
# get ara and lac genes
lac_inds = [ii for ii,this_gene in enumerate(all_genes_filter) if 'lac' in this_gene]
ara_inds = [ii for ii,this_gene in enumerate(all_genes_filter) if 'ara' in this_gene]
lac_genes = [this_gene for ii,this_gene in enumerate(all_genes_filter) if 'lac' in this_gene]
ara_genes = [this_gene for ii,this_gene in enumerate(all_genes_filter) if 'ara' in this_gene]
print(ara_genes+lac_genes)
my_genes = ara_genes + lac_genes
my_inds = ara_inds + lac_inds
# Out:
# ['araA', 'araB', 'araC', 'araD', 'araE', 'araF', 'araG', 'araH', 'araJ', 'lacA', 'lacI', 'lacY', 'lacZ']

# %%
# get the snapshots
snapshot_dict = snapshots_from_df(df_tpm_filter)

Yp = snapshot_dict['wt']['37']['11']['Yp']
Yf = snapshot_dict['wt']['37']['11']['Yf']

# subset to keep only the desired genes
Yp_normed, Yf_normed = apply_normalizer(Yp,Yf)
Yp_normed, Yf_normed = Yp_normed[my_inds], Yf_normed[my_inds]

# %%
# compute the noise (of the noise), where was this motivated from?
lambda_val_vec_p = np.expand_dims(np.std(Yp_normed,axis=1),axis=1)
lambda_val_vec_f = np.expand_dims(np.std(Yf_normed,axis=1),axis=1)
lambda_val_vec = np.std(np.hstack( (lambda_val_vec_p,lambda_val_vec_f)),axis=1)

K = calc_Koopman(Yf_normed,Yp_normed,flag=2,lambda_val=lambda_val_vec,noise_scaler=1)

######## Visualize host-interactions as heatmap ############
fig = plt.figure(figsize=(8,6.5))
hm = sns.heatmap(K,linewidths=0.005,cmap=my_cmap,xticklabels=my_genes,yticklabels=my_genes,
            linecolor='k',square=True,annot=True,annot_kws={"size":11},fmt='2.1f',cbar_kws={'shrink':0.9},
           center=0)
plt.xticks(fontsize=14,rotation='vertical'); plt.yticks(fontsize=12,rotation='horizontal')
plt.tight_layout()
plt.show()
# Out:
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.67e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 2.23e-01  7.48e-01  5.56e-02 -5.78e-02  1.04e-03  5.79e-17  2.36e-03
#     14| 1.21e-11  1.24e-11  1.86e-12 -9.97e-13  8.65e-13  5.11e-18  4.09e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.11e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.83e-06s
# 	Cones: avg projection time: 7.78e-05s
# 	Acceleration: avg step time: 2.17e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.0086e-12, dist(y, K*) = 6.4541e-11, s'y/|s||y| = -9.6301e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.2081e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.2395e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.8625e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.415e-23

# %%
# get colormap for the learned K 
vcenter = 0
vmin, vmax = K.min(), K.max()
normalize = mcolors.TwoSlopeNorm(vcenter=vcenter, vmin=vmin, vmax=vmax)
scalarmappable = cm.ScalarMappable(norm=normalize,cmap=my_cmap)
scalarmappable.set_array(K)

# %% [markdown]
# - How does LASSO do in terms of sparsity?

# %%
K = calc_Koopman(Yf_normed,Yp_normed,flag=2,lambda_val=0.001,verbose=False)

######## Visualize host-interactions as heatmap ############
fig = plt.figure(figsize=(8,6.5))
hm = sns.heatmap(K,linewidths=0.005,cmap=my_cmap,xticklabels=my_genes,yticklabels=my_genes,
            linecolor='k',square=True,annot=True,annot_kws={"size":11},fmt='2.1f',cbar_kws={'shrink':0.9},
           center=0)
plt.xticks(fontsize=14,rotation='vertical'); plt.yticks(fontsize=12,rotation='horizontal')
plt.tight_layout()
plt.show()

# %%
vcenter = 0
vmin, vmax = K.min(), K.max()
normalize = mcolors.TwoSlopeNorm(vcenter=vcenter, vmin=vmin, vmax=vmax)
scalarmappable_lasso = cm.ScalarMappable(norm=normalize,cmap=my_cmap)
scalarmappable_lasso.set_array(K)

# %% [markdown]
# #### Compare robust DMD to DMD with lasso penalization
# - To do this, we will run a leave-one-out experiment and report the average test error for each of the two model types with varying magnitude of regularization

# %%
# ndatapts - 1  train/test splits
kf = KFold(n_splits=Yp_normed.shape[1])

# %%
# perform robust optimization as \lambda is varied. consider the average test MSE over the learned models
noise_scaler_list = list(np.logspace(-3,3,100))
avg_val_MSE = []
for noise_scaler in noise_scaler_list: 
    val_MSE_list = []
    for train_index, test_index in kf.split(Yp_normed.T):
        print("TRAIN:", train_index, "TEST:", test_index)
        Yp_train, Yp_test = Yp_normed[:,train_index], Yp_normed[:,test_index]
        Yf_train, Yf_test = Yf_normed[:,train_index], Yf_normed[:,test_index]
        # compute the noise (of the noise), where was this motivated from? 
        lambda_val_vec_p = np.expand_dims(np.std(Yp_train,axis=1),axis=1)
        lambda_val_vec_f = np.expand_dims(np.std(Yf_train,axis=1),axis=1)
        lambda_val_vec = np.std(np.hstack( (lambda_val_vec_p,lambda_val_vec_f)),axis=1)
        K = calc_Koopman(Yf_train,Yp_train,flag=2,lambda_val=lambda_val_vec,noise_scaler=noise_scaler,
                         verbose=False)
        val_MSE = mean_squared_error(Yf_test,K@Yp_test)
#         val_MSE = np.linalg.norm(K@Yp_test - Yf_test)**2/(Yp_test.shape[1])
        val_MSE_list.append(val_MSE)
        print('Validation MSE = ' + '{:0.3e}'.format(val_MSE) )
        print('-'*50)
    avg_val_MSE.append(np.mean(val_MSE_list))
    print('Average validation MSE = ' + '{:0.3e}'.format(avg_val_MSE[0]) )
# Out:
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.006e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.823e-23
# Validation MSE = 1.679e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.848e-23
# Validation MSE = 6.688e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.266e-17
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.961e-23
# Validation MSE = 1.679e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.932e-23
# Validation MSE = 6.691e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.804e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.377e-23
# Validation MSE = 1.679e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.130e-23
# Validation MSE = 6.694e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.667e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.374e-23
# Validation MSE = 1.679e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.630e-23
# Validation MSE = 6.698e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.770e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.452e-23
# Validation MSE = 1.679e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.525e-24
# Validation MSE = 6.703e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.053e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.591e-23
# Validation MSE = 1.680e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.460e-23
# Validation MSE = 6.707e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.632e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.344e-24
# Validation MSE = 1.685e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.434e-23
# Validation MSE = 6.712e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.914e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.077e-23
# Validation MSE = 1.691e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.396e-24
# Validation MSE = 6.719e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.005e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.306e-24
# Validation MSE = 1.697e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.199e-23
# Validation MSE = 6.726e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.798e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.085e-24
# Validation MSE = 1.703e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.517e-23
# Validation MSE = 6.733e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.870e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.898e-23
# Validation MSE = 1.710e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.537e-23
# Validation MSE = 6.632e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.280e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.245e-23
# Validation MSE = 1.720e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.068e-23
# Validation MSE = 6.435e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.708e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.172e-23
# Validation MSE = 1.733e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.530e-23
# Validation MSE = 6.235e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.190e-24
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.177e-22
# Validation MSE = 1.747e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.016e-24
# Validation MSE = 5.925e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.927e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.954e-23
# Validation MSE = 1.763e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.885e-23
# Validation MSE = 5.593e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.776e-23
# Validation MSE = 3.443e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.222e-23
# Validation MSE = 1.780e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.391e-24
# Validation MSE = 5.255e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.246e-23
# Validation MSE = 3.444e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.177e-24
# Validation MSE = 1.798e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.184e-23
# Validation MSE = 4.910e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.636e-23
# Validation MSE = 3.445e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.534e-24
# Validation MSE = 1.818e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.044e-24
# Validation MSE = 4.468e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.582e-23
# Validation MSE = 3.448e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.250e-23
# Validation MSE = 1.839e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.056e-23
# Validation MSE = 3.702e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.493e-23
# Validation MSE = 3.451e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.477e-23
# Validation MSE = 1.860e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.647e-24
# Validation MSE = 2.996e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.897e-24
# Validation MSE = 3.456e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.354e-23
# Validation MSE = 1.888e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.233e-23
# Validation MSE = 2.422e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.531e-24
# Validation MSE = 3.462e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.190e-23
# Validation MSE = 1.925e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.050e-23
# Validation MSE = 1.940e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.785e-23
# Validation MSE = 3.470e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.391e-24
# Validation MSE = 1.964e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.853e-24
# Validation MSE = 1.439e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.435e-23
# Validation MSE = 3.480e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.935e-23
# Validation MSE = 2.004e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.169e-23
# Validation MSE = 1.099e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.583e-23
# Validation MSE = 3.489e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.268e-22
# Validation MSE = 2.042e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.004e-23
# Validation MSE = 8.799e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.712e-23
# Validation MSE = 3.502e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.839e-23
# Validation MSE = 2.077e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.727e-23
# Validation MSE = 7.471e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.546e-23
# Validation MSE = 3.517e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.974e-23
# Validation MSE = 2.110e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.870e-23
# Validation MSE = 6.746e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.692e-23
# Validation MSE = 3.532e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.305e-23
# Validation MSE = 2.141e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.116e-24
# Validation MSE = 6.417e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.456e-24
# Validation MSE = 3.546e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.693e-23
# Validation MSE = 2.170e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.785e-24
# Validation MSE = 6.334e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.419e-23
# Validation MSE = 3.561e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.626e-23
# Validation MSE = 2.198e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.937e-24
# Validation MSE = 6.386e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.866e-23
# Validation MSE = 3.581e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.965e-23
# Validation MSE = 2.225e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.061e-23
# Validation MSE = 6.499e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.844e-24
# Validation MSE = 3.603e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.768e-24
# Validation MSE = 2.251e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.041e-23
# Validation MSE = 6.628e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.690e-24
# Validation MSE = 3.626e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.392e-24
# Validation MSE = 2.278e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.383e-23
# Validation MSE = 6.747e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.013e-22
# Validation MSE = 3.650e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.382e-23
# Validation MSE = 2.313e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.561e-23
# Validation MSE = 6.848e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.961e-23
# Validation MSE = 3.673e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.660e-23
# Validation MSE = 2.353e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.780e-24
# Validation MSE = 6.935e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.392e-23
# Validation MSE = 3.698e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.892e-23
# Validation MSE = 2.388e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.880e-23
# Validation MSE = 7.023e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.917e-23
# Validation MSE = 3.722e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.903e-24
# Validation MSE = 2.419e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.502e-23
# Validation MSE = 7.130e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.017e-23
# Validation MSE = 3.747e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.606e-23
# Validation MSE = 2.446e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.326e-23
# Validation MSE = 7.281e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.538e-23
# Validation MSE = 3.784e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.711e-23
# Validation MSE = 2.474e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.326e-23
# Validation MSE = 7.487e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.354e-23
# Validation MSE = 3.809e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.340e-24
# Validation MSE = 2.504e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.722e-24
# Validation MSE = 7.669e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.131e-24
# Validation MSE = 3.828e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.772e-23
# Validation MSE = 2.530e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.056e-22
# Validation MSE = 7.814e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.253e-23
# Validation MSE = 3.842e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.034e-23
# Validation MSE = 2.562e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.115e-23
# Validation MSE = 7.988e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.259e-23
# Validation MSE = 3.851e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.883e-24
# Validation MSE = 2.587e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.568e-23
# Validation MSE = 8.255e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.725e-23
# Validation MSE = 3.856e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.183e-23
# Validation MSE = 2.613e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.635e-23
# Validation MSE = 8.515e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.912e-24
# Validation MSE = 3.857e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.968e-24
# Validation MSE = 2.636e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.123e-23
# Validation MSE = 8.773e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.837e-24
# Validation MSE = 3.854e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.697e-23
# Validation MSE = 2.655e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.603e-23
# Validation MSE = 9.053e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.729e-22
# Validation MSE = 3.848e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.148e-24
# Validation MSE = 2.669e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.733e-24
# Validation MSE = 9.364e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.388e-23
# Validation MSE = 3.839e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.140e-24
# Validation MSE = 2.679e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.707e-23
# Validation MSE = 9.770e-06
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.405e-23
# Validation MSE = 3.827e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.538e-24
# Validation MSE = 2.687e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.378e-23
# Validation MSE = 1.039e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.687e-24
# Validation MSE = 3.812e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.208e-24
# Validation MSE = 2.694e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.599e-24
# Validation MSE = 1.114e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.460e-24
# Validation MSE = 3.794e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.505e-23
# Validation MSE = 2.701e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.572e-24
# Validation MSE = 1.226e-05
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.960e-23
# Validation MSE = 3.776e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.867e-24
# Validation MSE = 2.706e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# ...
# [INFO]: CVXPY problem status: optimal
# MSE =  2.593e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.804e-22
# Validation MSE = 8.198e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.747e-23
# Validation MSE = 3.151e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.246e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.743e-22
# Validation MSE = 8.938e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.848e-24
# Validation MSE = 3.236e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.290e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.199e-23
# Validation MSE = 9.586e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.681e-22
# Validation MSE = 3.314e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.101e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.379e-23
# Validation MSE = 1.020e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.600e-19
# Validation MSE = 3.384e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.569e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.567e-22
# Validation MSE = 1.079e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.023e-22
# Validation MSE = 3.447e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.939e-24
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.833e-21
# Validation MSE = 1.132e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.310e-24
# Validation MSE = 3.503e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.917e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.150e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.944e-22
# Validation MSE = 3.553e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.160e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.552e-21
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.697e-22
# Validation MSE = 3.597e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.410e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.258e-21
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.417e-22
# Validation MSE = 3.636e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.806e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.850e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.123e-23
# Validation MSE = 3.670e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.066e-24
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.072e-22
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.723e-23
# Validation MSE = 3.700e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  6.182e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.684e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.625e-21
# Validation MSE = 3.727e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.036e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.612e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.643e-22
# Validation MSE = 3.751e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.253e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  1.440e-21
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.215e-22
# Validation MSE = 3.771e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.032e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  3.925e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  9.671e-22
# Validation MSE = 3.789e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.372e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  4.465e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.862e-22
# Validation MSE = 3.805e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  7.935e-23
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  8.216e-23
# Validation MSE = 1.156e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  5.134e-20
# Validation MSE = 3.818e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# WARN: m less than n, problem likely degenerate
# [INFO]: CVXPY problem status: optimal
# MSE =  2.731e-22
# Validation MSE = 3.036e-04
# --------------------------------------------------
# Average validation MSE = 6.967e-04

# %%
# perform lasso regression as \lambda is varied. consider the average test MSE over the learned models
noise_scaler_list = list(np.logspace(-3,3,100))
avg_val_MSE_lasso = []
for noise_scaler in noise_scaler_list: 
    val_MSE_list = []
    for train_index, test_index in kf.split(Yp_normed.T):
        print("TRAIN:", train_index, "TEST:", test_index)
        Yp_train, Yp_test = Yp_normed[:,train_index], Yp_normed[:,test_index]
        Yf_train, Yf_test = Yf_normed[:,train_index], Yf_normed[:,test_index]
        K = calc_Koopman(Yf_train,Yp_train,flag=2,lambda_val=float(noise_scaler),verbose=False)
        val_MSE = mean_squared_error(Yf_test,K@Yp_test)
#         val_MSE = np.linalg.norm(K@Yp_test - Yf_test)**2/(Yp_test.shape[1])
        val_MSE_list.append(val_MSE)
        print('Validation MSE = ' + '{:0.3e}'.format(val_MSE) )
        print('-'*50)
    avg_val_MSE_lasso.append(np.mean(val_MSE_list))
    print('Average validation MSE = ' + '{:0.3e}'.format(avg_val_MSE_lasso[0]) )
# Out:
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.034e-10
# Validation MSE = 4.383e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.397e-10
# Validation MSE = 3.534e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.544e-10
# Validation MSE = 1.674e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.834e-10
# Validation MSE = 4.374e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.780e-10
# Validation MSE = 3.605e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  8.029e-11
# Validation MSE = 1.177e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.877e-11
# Validation MSE = 4.367e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.672e-10
# Validation MSE = 3.620e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.364e-07
# Validation MSE = 1.970e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.710e-10
# Validation MSE = 4.366e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.546e-10
# Validation MSE = 3.727e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.543e-04
# Validation MSE = 1.193e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.345e-10
# Validation MSE = 4.367e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  8.404e-11
# Validation MSE = 3.760e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.354e-04
# Validation MSE = 1.134e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.792e-10
# Validation MSE = 4.367e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.435e-10
# Validation MSE = 3.756e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.004e-03
# Validation MSE = 1.477e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  9.221e-11
# Validation MSE = 4.367e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.140e-10
# Validation MSE = 3.894e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.229e-03
# Validation MSE = 2.036e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.264e-10
# Validation MSE = 4.392e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.426e-04
# Validation MSE = 3.166e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.240e-03
# Validation MSE = 2.136e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.318e-10
# Validation MSE = 4.378e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  8.243e-04
# Validation MSE = 2.376e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.573e-03
# Validation MSE = 2.406e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.644e-10
# Validation MSE = 4.397e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.670e-03
# Validation MSE = 2.878e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.831e-03
# Validation MSE = 2.520e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  9.411e-06
# Validation MSE = 4.602e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.997e-03
# Validation MSE = 3.034e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.468e-03
# Validation MSE = 2.856e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.002e-05
# Validation MSE = 4.604e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.550e-03
# Validation MSE = 3.376e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.491e-03
# Validation MSE = 2.986e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.006e-05
# Validation MSE = 4.608e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.758e-03
# Validation MSE = 4.069e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.498e-03
# Validation MSE = 3.029e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.022e-05
# Validation MSE = 4.598e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.807e-03
# Validation MSE = 3.729e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.506e-03
# Validation MSE = 3.002e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.027e-05
# Validation MSE = 4.600e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.823e-03
# Validation MSE = 3.694e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.514e-03
# Validation MSE = 3.080e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.058e-05
# Validation MSE = 4.617e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.849e-03
# Validation MSE = 3.694e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.533e-03
# Validation MSE = 3.070e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.111e-05
# Validation MSE = 4.606e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.922e-03
# Validation MSE = 3.681e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.591e-03
# Validation MSE = 3.071e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.132e-05
# Validation MSE = 4.618e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.079e-03
# Validation MSE = 3.478e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.746e-03
# Validation MSE = 3.143e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.229e-05
# Validation MSE = 4.628e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.402e-03
# Validation MSE = 3.221e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.120e-03
# Validation MSE = 3.584e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.412e-05
# Validation MSE = 4.583e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.555e-03
# Validation MSE = 2.851e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.081e-03
# Validation MSE = 2.878e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.730e-05
# Validation MSE = 4.754e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.694e-03
# Validation MSE = 2.365e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.244e-03
# Validation MSE = 2.207e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.231e-05
# Validation MSE = 4.642e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.943e-03
# Validation MSE = 2.354e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.226e-03
# Validation MSE = 2.245e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.247e-05
# Validation MSE = 4.647e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.052e-03
# Validation MSE = 3.504e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  8.380e-03
# Validation MSE = 4.444e-04
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.198e-04
# Validation MSE = 5.256e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.245e-02
# Validation MSE = 7.307e-04
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.657e-02
# Validation MSE = 1.221e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.230e-03
# Validation MSE = 6.672e-04
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.290e-02
# Validation MSE = 1.569e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  2.634e-02
# Validation MSE = 2.268e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  1.721e-02
# Validation MSE = 1.616e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.135e-02
# Validation MSE = 2.241e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.309e-02
# Validation MSE = 3.003e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  3.181e-02
# Validation MSE = 2.280e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.143e-02
# Validation MSE = 3.083e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.804e-02
# Validation MSE = 4.750e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  4.018e-02
# Validation MSE = 2.660e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.970e-02
# Validation MSE = 4.683e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.019e-02
# Validation MSE = 3.451e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# ...
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04
# TRAIN: [1 2] TEST: [0]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  7.187e-02
# Validation MSE = 3.882e-03
# --------------------------------------------------
# TRAIN: [0 2] TEST: [1]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  6.412e-02
# Validation MSE = 5.074e-03
# --------------------------------------------------
# TRAIN: [0 1] TEST: [2]
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 2), (13, 2)
# [INFO]: CVXPY problem status: optimal
# MSE =  5.822e-02
# Validation MSE = 5.983e-03
# --------------------------------------------------
# Average validation MSE = 3.197e-04

# %%
plt.figure(figsize=(4,4))
plt.rcParams.update({'font.size':18})
plt.plot(noise_scaler_list,avg_val_MSE,lw=2,label='Robust',color='k')
plt.plot(noise_scaler_list,avg_val_MSE_lasso,lw=2,label='LASSO',color='k',linestyle='--')
plt.xlabel(r'$\lambda$')
plt.ylabel('Validation MSE')
plt.legend(frameon=False)
plt.xscale('log')
plt.ticklabel_format(axis='y', style='sci',scilimits=(0,0),useMathText=True)
# plt.savefig(figDir+'fig2/robust_lasso_comparison.pdf',bbox_inches='tight',dpi=300,transparent=True)
plt.show()

# %%
noise_scaler_list = list(np.linspace(1e-3,1e3,250))
K_list = [] # was easier this way for plotting purposes, though have the tensor of K's is more intuitive
K_tensor = np.zeros((len(my_genes),len(my_genes),len(noise_scaler_list)))
MSE_list = []
for ii,noise_scaler in enumerate(noise_scaler_list):
    K = calc_Koopman(Yf_normed,Yp_normed,flag=2,lambda_val=lambda_val_vec,noise_scaler=noise_scaler)
    K_list.append(K)
    K_tensor[:,:,ii] = K
    mse = np.linalg.norm(K@Yp_normed - Yf_normed)**2/Yp_normed.shape[1]
    MSE_list.append(mse)

# %% [markdown]
# #### Build empirical distribution over $\lambda$

# %% [markdown]
# - First, robust optimization

# %%
# compute the noise (of the noise), where was this motivated from?
lambda_val_vec_p = np.expand_dims(np.std(Yp_normed,axis=1),axis=1)
lambda_val_vec_f = np.expand_dims(np.std(Yf_normed,axis=1),axis=1)
lambda_val_vec = np.std(np.hstack( (lambda_val_vec_p,lambda_val_vec_f)),axis=1)

noise_scaler_list = list(np.logspace(-3,3,1000))
K_list = [] # was easier this way for plotting purposes, though have the tensor of K's is more intuitive
K_tensor = np.zeros((len(my_genes),len(my_genes),len(noise_scaler_list)))
MSE_list = []
for ii,noise_scaler in enumerate(noise_scaler_list):
    K = calc_Koopman(Yf_normed,Yp_normed,flag=2,lambda_val=lambda_val_vec,noise_scaler=noise_scaler)
    K_list.append(K)
    K_tensor[:,:,ii] = K
    mse = np.linalg.norm(K@Yp_normed - Yf_normed)**2/Yp_normed.shape[1]
    MSE_list.append(mse)
# Out:
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.70e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.47e-17  1.23e-03
#     12| 1.16e-11  2.18e-12  2.80e-12  5.38e-13  3.34e-12  2.41e-17  2.73e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.74e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.72e-06s
# 	Cones: avg projection time: 7.86e-05s
# 	Acceleration: avg step time: 1.93e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.5327e-12, dist(y, K*) = 1.3674e-11, s'y/|s||y| = 3.1909e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.1563e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.1827e-12
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.8006e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.976e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.61e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.47e-17  1.26e-03
#     11| 8.99e-12  7.85e-11  6.87e-12  1.66e-12 -5.21e-12  1.40e-17  2.36e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.37e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.27e-06s
# 	Cones: avg projection time: 6.58e-05s
# 	Acceleration: avg step time: 1.48e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.8996e-12, dist(y, K*) = 1.4588e-11, s'y/|s||y| = -1.2705e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 8.9872e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 7.8457e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.8722e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.396e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.09e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.47e-17  1.38e-03
#     12| 1.21e-11  2.81e-11  1.21e-11 -8.39e-13  1.13e-11  2.05e-17  2.60e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.62e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.11e-06s
# 	Cones: avg projection time: 6.31e-05s
# 	Acceleration: avg step time: 1.46e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.8073e-12, dist(y, K*) = 3.3788e-11, s'y/|s||y| = 3.7795e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.2072e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.8094e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.2119e-11
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  3.062e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.05e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.46e-17  8.15e-02
#     12| 6.99e-12  3.91e-11  3.15e-12 -5.20e-13  2.63e-12  3.57e-17  8.29e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 8.29e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.23e-06s
# 	Cones: avg projection time: 6.32e-05s
# 	Acceleration: avg step time: 1.50e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.5382e-12, dist(y, K*) = 4.5881e-11, s'y/|s||y| = -8.8731e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.9949e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 3.9139e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 3.1524e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  4.892e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.05e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.46e-17  1.12e-03
#     11| 7.31e-12  2.07e-11  4.59e-12  6.66e-14  4.66e-12  5.55e-17  2.52e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.53e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.47e-06s
# 	Cones: avg projection time: 6.68e-05s
# 	Acceleration: avg step time: 2.26e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.9698e-12, dist(y, K*) = 1.8389e-11, s'y/|s||y| = -4.8015e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 7.3052e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.0679e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.5893e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  3.191e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.11e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.46e-17  1.04e-03
#     11| 1.11e-11  5.46e-11  1.41e-12 -1.80e-12 -3.91e-13  5.69e-18  2.45e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.46e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.47e-06s
# 	Cones: avg projection time: 6.25e-05s
# 	Acceleration: avg step time: 1.50e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.9798e-12, dist(y, K*) = 3.1701e-11, s'y/|s||y| = 1.1084e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.1094e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 5.4554e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.4064e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.070e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.42e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.56e-02 -3.65e-02  4.55e-04  6.46e-17  5.26e-02
#     13| 3.31e-12  1.66e-11  1.79e-13 -3.99e-13 -5.77e-13  3.06e-17  5.41e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.41e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.90e-06s
# 	Cones: avg projection time: 7.97e-05s
# 	Acceleration: avg step time: 1.86e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.8332e-12, dist(y, K*) = 1.9457e-11, s'y/|s||y| = -1.8278e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.3125e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.6551e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.7854e-13
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  3.959e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 9.69e-04s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.65e-02  4.54e-04  6.46e-17  1.13e-03
#     11| 1.28e-11  5.67e-11  2.07e-12 -3.20e-12 -5.28e-12  2.54e-18  2.18e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.19e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.90e-06s
# 	Cones: avg projection time: 5.85e-05s
# 	Acceleration: avg step time: 1.29e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.3467e-12, dist(y, K*) = 4.2837e-12, s'y/|s||y| = -7.2565e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.2810e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 5.6743e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.0739e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.726e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.84e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.65e-02  4.54e-04  6.46e-17  1.66e-03
#     11| 1.16e-11  5.81e-11  1.33e-12 -1.51e-12 -1.85e-13  3.08e-17  2.80e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.81e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.13e-06s
# 	Cones: avg projection time: 5.93e-05s
# 	Acceleration: avg step time: 1.45e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 6.9915e-12, dist(y, K*) = 7.9897e-12, s'y/|s||y| = -1.8407e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.1557e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 5.8091e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.3275e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.124e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.37e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.65e-02  4.54e-04  6.45e-17  6.27e-02
#     11| 1.07e-11  4.62e-11  1.93e-12  1.73e-12 -2.06e-13  1.76e-17  6.44e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 6.44e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 4.65e-06s
# 	Cones: avg projection time: 8.97e-05s
# 	Acceleration: avg step time: 2.16e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.6828e-12, dist(y, K*) = 2.6388e-11, s'y/|s||y| = 4.7047e-03
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.0700e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.6246e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.9339e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  4.219e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.19e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.65e-02  4.54e-04  6.45e-17  1.13e-03
#     11| 6.57e-12  2.21e-11  4.07e-12  1.87e-12 -2.20e-12  2.25e-17  3.00e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.01e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.93e-06s
# 	Cones: avg projection time: 5.79e-05s
# 	Acceleration: avg step time: 1.33e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.7040e-14, dist(y, K*) = 2.5468e-11, s'y/|s||y| = 1.8812e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.5748e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.2124e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.0666e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.627e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 4.14e-02s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.65e-02  4.54e-04  6.45e-17  2.84e-03
#     11| 8.30e-12  4.24e-11  1.03e-12  6.90e-14  1.09e-12  1.77e-17  4.88e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.90e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 4.82e-06s
# 	Cones: avg projection time: 9.08e-05s
# 	Acceleration: avg step time: 2.17e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.7535e-12, dist(y, K*) = 4.3186e-12, s'y/|s||y| = -3.3130e-03
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 8.2988e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.2362e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.0253e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.309e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.37e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.66e-02  4.54e-04  6.45e-17  4.29e-02
#     11| 6.40e-12  2.89e-11  2.44e-12  1.29e-13 -2.31e-12  1.39e-17  4.42e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.42e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.63e-06s
# 	Cones: avg projection time: 6.20e-05s
# 	Acceleration: avg step time: 1.59e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.7153e-12, dist(y, K*) = 1.1365e-11, s'y/|s||y| = -2.3791e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.4030e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.8936e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.4397e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.600e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.24e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.67e-01  3.57e-02 -3.66e-02  4.54e-04  6.45e-17  1.63e-03
#     11| 1.99e-11  9.10e-11  3.97e-13  2.60e-12  2.21e-12  3.98e-17  2.97e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.98e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.26e-06s
# 	Cones: avg projection time: 6.48e-05s
# 	Acceleration: avg step time: 1.50e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.7345e-12, dist(y, K*) = 4.7834e-11, s'y/|s||y| = -9.5424e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.9934e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 9.0959e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 3.9708e-13
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  5.974e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.11e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.45e-17  1.74e-03
#     12| 8.39e-12  1.79e-11  2.74e-12 -1.78e-12  9.61e-13  2.73e-17  3.31e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.32e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.18e-06s
# 	Cones: avg projection time: 6.48e-05s
# 	Acceleration: avg step time: 1.48e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.4603e-12, dist(y, K*) = 2.3477e-11, s'y/|s||y| = -9.0330e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 8.3897e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.7897e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.7438e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.327e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 3.90e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.44e-17  3.96e-02
#     11| 1.79e-11  4.00e-11  6.69e-12  2.93e-13 -6.40e-12  2.03e-17  4.12e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.13e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 4.89e-06s
# 	Cones: avg projection time: 6.84e-05s
# 	Acceleration: avg step time: 1.91e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 8.8229e-12, dist(y, K*) = 5.4410e-12, s'y/|s||y| = 8.3916e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.7893e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.0029e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.6881e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.034e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.11e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.44e-17  2.12e-03
#     11| 1.26e-11  2.42e-11  3.99e-12 -1.25e-12  2.74e-12  1.17e-17  3.45e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.47e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 4.34e-06s
# 	Cones: avg projection time: 6.18e-05s
# 	Acceleration: avg step time: 1.45e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.6298e-12, dist(y, K*) = 5.7526e-11, s'y/|s||y| = -1.3277e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.2555e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.4232e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 3.9871e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.963e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.56e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.44e-17  2.12e-03
#     11| 1.39e-11  3.66e-11  2.27e-12 -6.91e-13  1.58e-12  2.64e-17  3.80e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.81e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.14e-06s
# 	Cones: avg projection time: 7.05e-05s
# 	Acceleration: avg step time: 1.79e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.8272e-12, dist(y, K*) = 2.7341e-11, s'y/|s||y| = -3.8278e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.3938e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 3.6588e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.2697e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  5.790e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.43e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.44e-17  3.48e-02
#     12| 9.53e-12  1.09e-11  1.64e-12  9.82e-13  2.62e-12  3.34e-17  3.69e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.69e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 4.05e-06s
# 	Cones: avg projection time: 7.83e-05s
# 	Acceleration: avg step time: 2.42e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.7888e-12, dist(y, K*) = 6.6832e-12, s'y/|s||y| = 3.6571e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 9.5274e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.0941e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.6398e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.721e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 3.04e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.44e-17  2.36e-03
#     15| 1.54e-11  3.78e-11  3.54e-12  5.01e-13  4.04e-12  1.83e-17  4.25e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.26e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.14e-06s
# 	Cones: avg projection time: 6.37e-05s
# 	Acceleration: avg step time: 1.55e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.7552e-12, dist(y, K*) = 2.3253e-11, s'y/|s||y| = -1.1622e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.5432e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 3.7763e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 3.5396e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  6.533e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.76e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.44e-17  3.74e-03
#     13| 1.06e-11  6.03e-11  6.57e-12  1.04e-12 -5.53e-12  2.54e-17  5.57e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.58e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 4.43e-06s
# 	Cones: avg projection time: 6.56e-05s
# 	Acceleration: avg step time: 1.84e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 5.3190e-13, dist(y, K*) = 3.0979e-11, s'y/|s||y| = 1.6459e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.0642e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 6.0350e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.5741e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  4.320e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.56e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.57e-02 -3.66e-02  4.54e-04  6.43e-17  2.55e-02
#     11| 1.04e-11  2.80e-11  1.68e-12 -2.81e-13  1.40e-12  2.58e-17  2.71e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 2.71e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.51e-06s
# 	Cones: avg projection time: 6.76e-05s
# 	Acceleration: avg step time: 1.62e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.2559e-12, dist(y, K*) = 1.7654e-11, s'y/|s||y| = -4.4951e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.0439e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 2.8006e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.6841e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  3.804e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.99e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.58e-02 -3.66e-02  4.54e-04  6.43e-17  1.96e-03
#     11| 9.00e-12  1.11e-11  8.17e-12 -7.49e-13  7.42e-12  5.29e-17  3.17e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.18e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.87e-06s
# 	Cones: avg projection time: 5.49e-05s
# 	Acceleration: avg step time: 1.33e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.8952e-12, dist(y, K*) = 2.9336e-12, s'y/|s||y| = -9.3230e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 9.0009e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.1054e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 8.1695e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.262e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 3.40e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.58e-02 -3.66e-02  4.54e-04  6.43e-17  1.76e-03
#     11| 1.45e-11  1.23e-10  7.76e-12  5.48e-13 -7.21e-12  8.02e-18  3.15e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.16e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.14e-06s
# 	Cones: avg projection time: 6.20e-05s
# 	Acceleration: avg step time: 1.45e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.1049e-12, dist(y, K*) = 5.3123e-11, s'y/|s||y| = 1.7864e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.4474e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.2292e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 7.7580e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.588e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.77e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.58e-02 -3.66e-02  4.54e-04  6.43e-17  2.87e-02
#     12| 1.31e-11  4.77e-11  4.78e-12 -1.80e-13  4.60e-12  6.32e-17  3.09e-02
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 3.09e-02s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.87e-06s
# 	Cones: avg projection time: 7.29e-05s
# 	Acceleration: avg step time: 1.79e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 6.2701e-12, dist(y, K*) = 5.0330e-12, s'y/|s||y| = 8.9433e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.3112e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 4.7664e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.7762e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  3.161e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.87e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.87e-01  6.68e-01  3.58e-02 -3.67e-02  4.54e-04  6.43e-17  2.39e-03
#     11| 9.93e-12  1.00e-11  1.21e-12 -1.25e-12 -4.01e-14  4.62e-18  4.17e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 4.19e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.21e-06s
# 	Cones: avg projection time: 6.30e-05s
# 	Acceleration: avg step time: 1.48e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.6136e-12, dist(y, K*) = 1.7111e-11, s'y/|s||y| = -1.7410e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 9.9346e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.0032e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.2144e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.272e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# ...
# 	sd vars: 136, sd blks: 1
# Setup time: 2.20e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.38e+20  1.09e+20  1.00e+00 -1.29e+21  1.36e+18  1.07e+20  2.58e-03
#     20| 4.74e-12  1.99e-10  9.20e-12  2.45e-11  1.53e-11  6.18e-16  5.52e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.53e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.75e-06s
# 	Cones: avg projection time: 6.35e-05s
# 	Acceleration: avg step time: 1.39e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.7489e-11, dist(y, K*) = 1.5049e-09, s'y/|s||y| = 4.1993e-03
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 4.7374e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.9896e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 9.1971e-12
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.978e-22
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.56e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.38e+20  1.09e+20  1.00e+00 -1.30e+21  1.38e+18  1.08e+20  5.00e-03
#     20| 2.71e-11  3.37e-10  4.21e-10 -3.02e-10  1.19e-10  5.94e-16  8.70e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 8.71e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.69e-06s
# 	Cones: avg projection time: 6.40e-05s
# 	Acceleration: avg step time: 1.38e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 4.2170e-11, dist(y, K*) = 1.6910e-09, s'y/|s||y| = -3.8512e-04
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.7064e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 3.3705e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 4.2081e-10
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  3.999e-21
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.08e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.38e+20  1.09e+20  1.00e+00 -1.32e+21  1.40e+18  1.09e+20  3.36e-03
#     18| 6.16e-12  8.56e-10  1.30e-11  1.08e-11 -2.25e-12  5.75e-16  5.86e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.87e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.74e-06s
# 	Cones: avg projection time: 6.34e-05s
# 	Acceleration: avg step time: 1.38e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 2.2947e-11, dist(y, K*) = 1.8074e-09, s'y/|s||y| = -1.3825e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 6.1634e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 8.5648e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.3024e-11
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.330e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.66e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.38e+20  1.09e+20  1.00e+00 -1.34e+21  1.41e+18  1.10e+20  5.07e-03
#     18| 2.90e-12  1.12e-10  3.00e-11  3.19e-11  1.94e-12  1.46e-16  8.50e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 8.52e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.10e-06s
# 	Cones: avg projection time: 6.62e-05s
# 	Acceleration: avg step time: 1.55e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.7542e-11, dist(y, K*) = 1.8024e-09, s'y/|s||y| = -6.4664e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.8973e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.1241e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.9965e-11
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = 0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.598e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.04e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.39e+20  1.09e+20  1.00e+00 -1.36e+21  1.42e+18  1.11e+20  2.85e-03
#     20| 2.66e-12  1.11e-10  6.54e-12 -8.13e-12 -1.58e-12  4.66e-17  9.16e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 9.18e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.91e-06s
# 	Cones: avg projection time: 7.98e-05s
# 	Acceleration: avg step time: 1.87e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.3507e-11, dist(y, K*) = 1.1172e-09, s'y/|s||y| = 7.3303e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.6576e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.1079e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.5437e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  1.775e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 2.17e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.39e+20  1.09e+20  1.00e+00 -1.38e+21  1.44e+18  1.12e+20  2.91e-03
#     19| 3.83e-12  1.82e-10  1.77e-11  1.68e-11 -9.45e-13  4.59e-17  5.22e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.23e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.85e-06s
# 	Cones: avg projection time: 6.29e-05s
# 	Acceleration: avg step time: 1.39e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.1213e-11, dist(y, K*) = 1.6394e-09, s'y/|s||y| = -2.4302e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 3.8332e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.8203e-10
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.7698e-11
# ----------------------------------------------------------------------------
# c'x = 0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  4.541e-23
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.70e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.39e+20  1.09e+20  1.00e+00 -1.40e+21  1.45e+18  1.13e+20  4.10e-03
#     20| 1.66e-11  1.21e-09  2.87e-11 -2.11e-12 -3.08e-11  1.45e-17  7.48e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 7.49e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 3.67e-06s
# 	Cones: avg projection time: 6.69e-05s
# 	Acceleration: avg step time: 1.52e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.8307e-11, dist(y, K*) = 1.6090e-09, s'y/|s||y| = 3.3608e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 1.6561e-11
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.2057e-09
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 2.8685e-11
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  7.713e-24
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 6.68e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.39e+20  1.09e+20  1.00e+00 -1.42e+21  1.47e+18  1.14e+20  2.38e-03
#     20| 8.20e-12  1.41e-09  1.20e-11 -1.26e-11 -2.46e-11  1.10e-15  5.37e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 5.38e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.99e-06s
# 	Cones: avg projection time: 6.64e-05s
# 	Acceleration: avg step time: 1.53e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 3.5046e-11, dist(y, K*) = 1.3575e-09, s'y/|s||y| = -2.0422e-01
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 8.2044e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 1.4105e-09
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 1.2002e-11
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  2.271e-22
# [INFO]: CVXPY Koopman operator variable: (13, 13)
# [INFO]: Shape of Yf and Yp: (13, 3), (13, 3)
# ----------------------------------------------------------------------------
# 	SCS v2.1.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ----------------------------------------------------------------------------
# Lin-sys: sparse-direct, nnz in A = 1031
# eps = 1.00e-04, alpha = 1.50, max_iters = 1000000, normalize = 1, scale = 1.00
# acceleration_lookback = 10, rho_x = 1.00e-03
# Variables n = 171, constraints m = 176
# Cones:	soc vars: 40, soc blks: 1
# 	sd vars: 136, sd blks: 1
# Setup time: 1.97e-03s
# ----------------------------------------------------------------------------
#  Iter | pri res | dua res | rel gap | pri obj | dua obj | kap/tau | time (s)
# ----------------------------------------------------------------------------
#      0| 1.39e+20  1.10e+20  1.00e+00 -1.43e+21  1.48e+18  1.16e+20  4.60e-03
#     18| 2.70e-12  7.98e-11  6.77e-12 -7.06e-12 -2.85e-13  3.81e-16  7.49e-03
# ----------------------------------------------------------------------------
# Status: Solved
# Timing: Solve time: 7.50e-03s
# 	Lin-sys: nnz in L factor: 1573, avg solve time: 2.76e-06s
# 	Cones: avg projection time: 6.20e-05s
# 	Acceleration: avg step time: 1.39e-05s
# ----------------------------------------------------------------------------
# Error metrics:
# dist(s, K) = 1.6107e-11, dist(y, K*) = 2.0146e-09, s'y/|s||y| = -7.7412e-02
# primal res: |Ax + s - b|_2 / (1 + |b|_2) = 2.7012e-12
# dual res:   |A'y + c|_2 / (1 + |c|_2) = 7.9755e-11
# rel gap:    |c'x + b'y| / (1 + |c'x| + |b'y|) = 6.7748e-12
# ----------------------------------------------------------------------------
# c'x = -0.0000, -b'y = -0.0000
# ============================================================================
# [INFO]: CVXPY problem status: optimal
# MSE =  6.631e-24

# %%
import matplotlib.ticker as tkr
formatter = tkr.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-2, 2))

plt.figure(figsize=(4,4))
sns.kdeplot(x=K_tensor[0,2,:],y=K_tensor[0,11,:],shade=True,cmap='Reds',levels=30,cbar=True, \
           cbar_kws={'ticks':[0.0005, 0.003, 0.011],'format':formatter})
plt.xlabel(r'$\mathbf{K}_{\mathrm{araA, araC}}$')
plt.ylabel(r'$\mathbf{K}_{\mathrm{araA, lacI}}$')
# plt.savefig(figDir+'fig2/robust_opt_K_araA_impact.pdf',transparent=True,bbox_inches='tight',dpi=300)
plt.show()

# %%
# plt.rcParams.update({'font.size':18})
fig, ax = plt.subplots(K_list[0].shape[0],K_list[0].shape[1],figsize=(14,7),sharey=False,sharex=False)
for ii in range(len(K_tensor)):
    for jj in range(len(K_tensor)):
        # plot Kij as a distribution over regularization parameter
        Kij_all = K_tensor[ii,jj,:] 
        sns.kdeplot(Kij_all,linewidth=3,shade=True,ax=ax[ii,jj],
                    color=scalarmappable.to_rgba(np.mean(Kij_all)))
        ax[ii,jj].set(ylabel=None)
        # apply gene labels
        if jj == 0:
            ax[ii,jj].set_ylabel((my_genes)[ii],rotation='horizontal',fontsize=18)
            ax[ii,jj].yaxis.set_label_coords(-0.45,0.2)
        if ii == len(K_list[0])-1: 
            ax[ii,jj].set_xlabel((ara_genes+lac_genes)[jj],fontsize=18,rotation='vertical')
            
#         ax[ii,jj].tick_params(axis='x',labelsize=14)
#         ax[ii,jj].set_xticks([np.round(np.min(Kij_all),2),np.round(np.max(Kij_all),2)])
#         ax[ii,jj].tick_params(axis='y',labelsize=14)
        ax[ii,jj].set_yticklabels([]); ax[ii,jj].set_xticklabels([]); 
        ax[ii,jj].set_yticks([]); ax[ii,jj].set_xticks([]);
        for side in ax[ii,jj].spines.keys():
                this_side = ax[ii,jj].spines[side]
                this_side.set_visible(False)
            
cbar = plt.colorbar(scalarmappable,ax=ax[:,:],shrink=0.9)
# cbar.set_label(r'Host-Host Interactions $\mathbf{K}_{hh}$',rotation=270)

plt.savefig(figDir+'fig2/robust_opt_K_varyReg.pdf',transparent=True,bbox_inches='tight',dpi=300)
# plt.tight_layout()
plt.show()

# %% [markdown]
# - Now LASSO

# %%
noise_scaler_list = list(np.logspace(-2,-1,250))
K_list = [] # was easier this way for plotting purposes, though have the tensor of K's is more intuitive
K_tensor = np.zeros((len(my_genes),len(my_genes),len(noise_scaler_list)))
MSE_list = []
for ii,noise_scaler in enumerate(noise_scaler_list):
    K = calc_Koopman(Yf_normed,Yp_normed,flag=2,lambda_val=float(noise_scaler),verbose=False)
    K_list.append(K)
    K_tensor[:,:,ii] = K
    mse = np.linalg.norm(K@Yp_normed - Yf_normed)**2/Yp_normed.shape[1]
    MSE_list.append(mse)

# %%
# plt.rcParams.update({'font.size':18})
fig, ax = plt.subplots(K_list[0].shape[0],K_list[0].shape[1],figsize=(15,9),sharey=False,sharex=False)
for ii in range(len(K_tensor)):
    for jj in range(len(K_tensor)):
        # plot Kij as a distribution over regularization parameter
        Kij_all = K_tensor[ii,jj,:] 
        sns.kdeplot(Kij_all,linewidth=3,shade=True,ax=ax[ii,jj],
                    color=scalarmappable.to_rgba(np.mean(Kij_all)))
        ax[ii,jj].set(ylabel=None)
        # apply gene labels
        if jj == 0:
            ax[ii,jj].set_ylabel((my_genes)[ii],rotation='horizontal',fontsize=18)
            ax[ii,jj].yaxis.set_label_coords(-0.45,0.2)
        if ii == len(K_list[0])-1: 
            ax[ii,jj].set_xlabel((ara_genes+lac_genes)[jj],fontsize=18,rotation='vertical')
            
#         ax[ii,jj].tick_params(axis='x',labelsize=14)
#         ax[ii,jj].set_xticks([np.round(np.min(Kij_all),2),np.round(np.max(Kij_all),2)])
#         ax[ii,jj].tick_params(axis='y',labelsize=14)
        ax[ii,jj].set_yticklabels([]); ax[ii,jj].set_xticklabels([]); 
        ax[ii,jj].set_yticks([]); ax[ii,jj].set_xticks([]);
        for side in ax[ii,jj].spines.keys():
                this_side = ax[ii,jj].spines[side]
                this_side.set_visible(False)
            
cbar = plt.colorbar(scalarmappable_lasso,ax=ax[:,:],shrink=0.9)
# cbar.set_label(r'$\mathbf{K}_{hh}$ Host-Host Koopman matrix',rotation=270)

# plt.savefig(figDir+'robust_opt_K_varyReg_xlabeled.pdf',transparent=True,bbox_inches='tight',dpi=300)
# plt.tight_layout()
plt.show()

# %%
sns.heatmap(K_tensor[:,:,0])
